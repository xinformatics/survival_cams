# %%
import pickle


with open('gene_coord.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for x in list(data)[0:3]:
    print (x)
# Out:
# (53, 53)
# (57, 50)
# (39, 70)

# %%
len(list(data))
# Out:
# 5351

# %%
import matplotlib.image as img
image = img.imread("class1_example2_saliency.png")

# %%
plt.imshow(image)

# %%
#3 prominent clusters are there for class0
# 1: H 40-45 and W 94-99
# 2: H 80-90 and W 70-80
# 3: H 15-25 and W 85-95

#3 prominent clusters are there for class1
# 1: H 50-60 and W 25-35
# 2: H 35-40 and W 60-70

# %%
#used stringDB to find connectivity, only high interactions, score > 0.7

# %%
temp = image

# %%
plt.imshow(temp[35:40,60:70])

# %%
#write a function to return cooordinates
for key, value in data.items():
    
    if ((35 < key[0] < 40) and (60 < key[1] < 70)):
        print (value)
        
        
#
# Out:
# ['LOC100302401', 'RASAL2', 'VCL']
# ['ACTBL2', 'CDH3']
# ['BARX2', 'C9orf84', 'GRHL3', 'KCNN4', 'S100A2']
# ['CNN2', 'IL4R', 'RIN1', 'SH2D3A', 'TNFRSF6B', 'TRIP10']
# ['XDH']
# ['ANGPTL4', 'ATP8B3', 'SLC16A3']
# ['CALB2', 'MSX2', 'TPM4']
# ['ASPH', 'CLVS1']
# ['CAMK2N1', 'FIBCD1', 'WNT7A']
# ['GNA15', 'PLAUR', 'PLIN3', 'RHOF', 'TICAM1']
# ['C11orf86', 'CATSPER1', 'CST6', 'NKX2-8', 'ST6GALNAC2', 'SYT12', 'VSTM2L']
# ['AHNAK2', 'BCAR3', 'LAMB3', 'LOC100216001', 'LOC338588']
# ['ARL4D', 'CDA', 'DUSP5', 'FOSL1', 'UBC']
# ['BATF3', 'DPY19L1', 'UPP1']
# ['MYH16', 'RGS20']
# ['C6orf218', 'MUC16', 'TFAP2A']
# ['CRABP2']
# ['DNAJB4', 'RND3', 'TLE1']
# ['ARHGAP10', 'DST', 'NEBL', 'NR2F2', 'WDFY2']
# ['S100A4', 'S100A5']
# ['PLXNA1']
# ['C20orf141', 'C4orf26', 'TH']
# ['ITGA2', 'PHLDA1', 'PRKCA']
# ['GPR111', 'GPR115', 'HTR1D', 'LIPK']
# ['ABTB2', 'APP', 'CLSTN1', 'ECE1', 'IRS1']
# ['CD109', 'CLCA3P', 'LAMC2', 'NEDD4', 'PGM2', 'ZNF185']
# ['EXT1', 'PCDH7', 'PDLIM5', 'PTPN12', 'SEMA3C', 'TPBG']
# ...
